# %% [markdown]
# <a href="https://colab.research.google.com/github/avani1998/data_science_bootcamp/blob/main/week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### 1. Define two custom numpy arrays, say A and B. Generate two new numpy arrays by stacking A and B vertically and horizontally.

# %%
import numpy as np
np.random.seed(42)
A = np.random.randint(100, size=6)
B = np.random.randint(100, size=6)
print("A=",A,"B=",B)
# Out:
# A= [51 92 14 71 60 20] B= [82 86 74 74 87 99]

# %%
C= np.vstack([A,B])
D = np.hstack([A,B])
print("C =",C,"\n",C.shape)
print("D =",D,"\n",D.shape)
# Out:
# C = [[51 92 14 71 60 20]
#  [82 86 74 74 87 99]]
#  (2, 6)
# D = [51 92 14 71 60 20 82 86 74 74 87 99]
#  (12,)

# %% [markdown]
# #### 2. Find common elements between A and B.

# %%
A1=[5,6,7,3,2,90,271,6251,71,82,128]
B1=[6,81,90,281,2,128,74,82,91,736]
np.intersect1d(A1, B1)
# Out:
# array([  2,   6,  82,  90, 128])

# %% [markdown]
# #### 3. Extract all numbers from A which are within a specific range. eg between 5 and 10. [Hint: np.where() might be useful or boolean masks]

# %%
result = [x for x in A if x > 50 and x < 100]
print(result)
# Out:
# [51, 92, 71, 60]

# %% [markdown]
# #### 4. Filter the rows of iris_2d that has petallength (3rd column) > 1.5 and sepallength (1st column) < 5.0
# 	url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
# 	iris_2d = np.genfromtxt(url, delimiter=',', dtype='float', usecols=[0,1,2,3])

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris = np.genfromtxt(url, delimiter=',', dtype='object')
names = ('sepallength', 'sepalwidth', 'petallength', 'petalwidth', 'species')


sepallength = iris[:, 0].astype('float')  # sepallength
sepalwidth = iris[:, 1].astype('float')  # sepalwidth
petallength = iris[:, 2].astype('float')  # petallength
petalwidth = iris[:, 3].astype('float')  # petalwidth
species = iris[:, 4]  # species

petallength_condition= petallength>1.5
sepallength_condition=sepallength<0.5

print("Flowers with petallength>1.5:",iris[petallength_condition])
print("Flowers with sepallength<0.5:",iris[sepallength_condition])

combined_data = petallength_condition & sepallength_condition
print(iris[combined_data])
# Out:
# Flowers with petallength>1.5: [[b'5.4' b'3.9' b'1.7' b'0.4' b'Iris-setosa']
#  [b'4.8' b'3.4' b'1.6' b'0.2' b'Iris-setosa']
#  [b'5.7' b'3.8' b'1.7' b'0.3' b'Iris-setosa']
#  [b'5.4' b'3.4' b'1.7' b'0.2' b'Iris-setosa']
#  [b'5.1' b'3.3' b'1.7' b'0.5' b'Iris-setosa']
#  [b'4.8' b'3.4' b'1.9' b'0.2' b'Iris-setosa']
#  [b'5.0' b'3.0' b'1.6' b'0.2' b'Iris-setosa']
#  [b'5.0' b'3.4' b'1.6' b'0.4' b'Iris-setosa']
#  [b'4.7' b'3.2' b'1.6' b'0.2' b'Iris-setosa']
#  [b'4.8' b'3.1' b'1.6' b'0.2' b'Iris-setosa']
#  [b'5.0' b'3.5' b'1.6' b'0.6' b'Iris-setosa']
#  [b'5.1' b'3.8' b'1.9' b'0.4' b'Iris-setosa']
#  [b'5.1' b'3.8' b'1.6' b'0.2' b'Iris-setosa']
#  [b'7.0' b'3.2' b'4.7' b'1.4' b'Iris-versicolor']
#  [b'6.4' b'3.2' b'4.5' b'1.5' b'Iris-versicolor']
#  [b'6.9' b'3.1' b'4.9' b'1.5' b'Iris-versicolor']
#  [b'5.5' b'2.3' b'4.0' b'1.3' b'Iris-versicolor']
#  [b'6.5' b'2.8' b'4.6' b'1.5' b'Iris-versicolor']
#  [b'5.7' b'2.8' b'4.5' b'1.3' b'Iris-versicolor']
# ...

# %% [markdown]
# There are no common flowers that have sepallength <0.5 and petallength >1.5

# %% [markdown]
# #### From df filter the 'Manufacturer', 'Model' and 'Type' for every 20th row starting from 1st (row 0).

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
df.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1          NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2         Audi       90  Compact       25.9   29.1       32.3      20.0
# 3         Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4          BMW     535i  Midsize        NaN   30.0        NaN      22.0
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0         31.0                None      Front  ...        5.0   177.0
# 1         25.0  Driver & Passenger      Front  ...        5.0   195.0
# 2         26.0         Driver only      Front  ...        5.0   180.0
# 3         26.0  Driver & Passenger        NaN  ...        6.0   193.0
# 4         30.0                 NaN       Rear  ...        4.0   186.0
#
#    Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# ...

# %%
result = df[['Manufacturer','Model','Type']][::20]
result.head()
# Out:
#    Manufacturer    Model     Type
# 0         Acura  Integra    Small
# 20     Chrysler  LeBaron  Compact
# 40        Honda  Prelude   Sporty
# 60      Mercury   Cougar  Midsize
# 80       Subaru   Loyale    Small

# %% [markdown]
# #### 2. Replace missing values in Min.Price and Max.Price columns with their respective mean.
#
# ```
# df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
# ```

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv')
df.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small       12.9   15.9       18.8      25.0
# 1          NaN   Legend  Midsize       29.2   33.9       38.7      18.0
# 2         Audi       90  Compact       25.9   29.1       32.3      20.0
# 3         Audi      100  Midsize        NaN   37.7       44.6      19.0
# 4          BMW     535i  Midsize        NaN   30.0        NaN      22.0
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0         31.0                None      Front  ...        5.0   177.0
# 1         25.0  Driver & Passenger      Front  ...        5.0   195.0
# 2         26.0         Driver only      Front  ...        5.0   180.0
# 3         26.0  Driver & Passenger        NaN  ...        6.0   193.0
# 4         30.0                 NaN       Rear  ...        4.0   186.0
#
#    Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# ...

# %%
mean_min = df['Min.Price'].mean()
mean_max=df['Max.Price'].mean()
df['Min.Price']=df['Min.Price'].fillna(mean_min)
df['Max.Price'] = df['Max.Price'].fillna(mean_max)

# %%
df.head()
# Out:
#   Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0        Acura  Integra    Small  12.900000   15.9  18.800000      25.0
# 1          NaN   Legend  Midsize  29.200000   33.9  38.700000      18.0
# 2         Audi       90  Compact  25.900000   29.1  32.300000      20.0
# 3         Audi      100  Midsize  17.118605   37.7  44.600000      19.0
# 4          BMW     535i  Midsize  17.118605   30.0  21.459091      22.0
#
#    MPG.highway             AirBags DriveTrain  ... Passengers  Length  \
# 0         31.0                None      Front  ...        5.0   177.0
# 1         25.0  Driver & Passenger      Front  ...        5.0   195.0
# 2         26.0         Driver only      Front  ...        5.0   180.0
# 3         26.0  Driver & Passenger        NaN  ...        6.0   193.0
# 4         30.0                 NaN       Rear  ...        4.0   186.0
#
#    Wheelbase  Width  Turn.circle Rear.seat.room  Luggage.room  Weight  \
# ...

# %% [markdown]
# #### 3. How to get the rows of a dataframe with row sum > 100?
# ```
# df = pd.DataFrame(np.random.randint(10, 40, 60).reshape(-1, 4))
# ```

# %%
df = pd.DataFrame(np.random.randint(10, 40, 60).reshape(-1, 4))
df.head()
# Out:
#     0   1   2   3
# 0  21  38  17  24
# 1  12  23  26  13
# 2  27  17  13  11
# 3  39  15  31  19
# 4  13  31  38  27

# %%
rows=df.sum(axis=1)
hundred = df[rows>100]
hundred.head()
# Out:
#      0   1   2   3
# 3   39  15  31  19
# 4   13  31  38  27
# 8   37  34  39  17
# 9   30  25  22  27
# 10  24  30  33  35
